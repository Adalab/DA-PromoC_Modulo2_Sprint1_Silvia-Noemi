# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Ejercicios Pair Programming - Módulo 2 Sprint 1
# ## Lección 4 - Pandas VI
# ### Noemi Azorin y Silvia Gordón

# %% [markdown]
# 1 - Cargad el csv que guardasteis ayer.
#
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.
#
# #df.dropna(inplace = True)

# %% [markdown]
# ¿Cuántas filas se han eliminado con esta línea de código?

# %%
#desplegamos todas las columnas para visualizarlo todo al detalle.
pd.options.display.max_columns = None

# %%
ataques = pd.read_csv("ficheros_pandas/attacks1.csv")
ataques.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
ataques.dropna(inplace=True)

# %% [markdown]
# - Antes de empezar a trabajar, exploramos el archivo.

# %%
ataques.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
ataques.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1502 entries, 0 to 5905
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  1502 non-null   object
#  1   unnamed:_0   1502 non-null   int64
#  2   year         1502 non-null   float64
#  3   type         1502 non-null   object
#  4   country      1502 non-null   object
#  5   area         1502 non-null   object
#  6   location     1502 non-null   object
#  7   activity     1502 non-null   object
#  8   name         1502 non-null   object
#  9   sex_         1502 non-null   object
#  10  age          1502 non-null   object
#  11  time         1502 non-null   object
#  12  species_     1502 non-null   object
#  13  href         1502 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 176.0+ KB

# %%
pd.isnull(ataques)
# Out:
#       case_number  unnamed:_0   year   type  country   area  location  \
# 0           False       False  False  False    False  False     False
# 6           False       False  False  False    False  False     False
# 8           False       False  False  False    False  False     False
# 10          False       False  False  False    False  False     False
# 13          False       False  False  False    False  False     False
# ...           ...         ...    ...    ...      ...    ...       ...
# 5528        False       False  False  False    False  False     False
# 5631        False       False  False  False    False  False     False
# 5667        False       False  False  False    False  False     False
# 5797        False       False  False  False    False  False     False
# 5905        False       False  False  False    False  False     False
#
#       activity   name   sex_    age   time  species_   href
# 0        False  False  False  False  False     False  False
# ...

# %% [markdown]
# 2 - ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
ataques_usa = ataques[ataques["country"] == "USA"]
ataques_usa.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 8  2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
#
#                        location  activity         name sex_ age   time  \
# 0   Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
# 8  Cocoa Beach, Brevard  County   Walking    Cody High    M  15  17h00
#
#          species_                                               href
# 0     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  Bull shark, 6'  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
print(f"En USA se han producido {ataques_usa.shape[0]} ataques.")
# Out:
# En USA se han producido 719 ataques.

# %% [markdown]
# 3 - ¿Y en España?

# %%
ataques_spain = ataques[ataques["country"] == "SPAIN"]
ataques_spain.head(2)
# Out:
#      case_number  unnamed:_0    year        type country            area  \
# 82  2017.09.16.b          82  2017.0  Unprovoked   SPAIN  Canary Islands
# 98  2017.08.26.b          98  2017.0     Invalid   SPAIN       Castellón
#
#            location      activity    name sex_ age    time  \
# 82    Gran Canaria   Body surfing    male    M  13     NaN
# 98  Grao de Moncofa      Swimming  female    F  11  Midday
#
#                           species_                investigator_or_source  \
# 82                Porbeagle, 1.5 m                      Turismo La Aldea
# 98  Shark involvement questionable  El Periodico Mediterraneo, 8/27/2017
#
#                              pdf  \
# 82  2017.09.16.b-GrandCanary.pdf
# 98        2017.08.26.b-Spain.pdf
#
#                                          href_formula  \
# 82  http://sharkattackfile.net/spreadsheets/pdf_di...
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %%
print(f"En España se han producido {ataques_spain.shape[0]} ataques.")
# Out:
# En España se han producido 42 ataques.

# %% [markdown]
# 3.1 - ¿En qué regiones se han producido los ataques (columna location)?

# %%
region = ataques_spain["location"]
region.head()
# Out:
# 82                      Gran Canaria
# 98                    Grao de Moncofa
# 113    Estanys Beach, Colonia de Sant
# 130                  Playa den Bossa
# 233                  Arenales del Sol
# Name: location, dtype: object

# %% [markdown]
# 3.2 - ¿Cuántos ataques se han producido en cada área (columna area) ?

# %%
area = ataques_spain["area"]
area.head()
# Out:
# 82        Canary Islands
# 98             Castellón
# 113              Majorca
# 130         Ibiza Island
# 233    Alicante Province
# Name: area, dtype: object

# %%
area.value_counts()
# Out:
# Canary Islands         7
# Catalonia              4
# Alicante               3
# Cádiz                  3
# Malaga                 2
# Valencia               2
# Grand Canary Island    2
# Galica                 1
# Eastern Catalona       1
# Galicia                1
# Andalucia              1
# Málaga                 1
# Balearics              1
# Gran Canaria           1
# Alicante Province      1
# Valencia               1
# Castellón              1
# Costa Blanca           1
# Catalunya              1
# Majorca                1
# Granada                1
# Ibiza Island           1
# Sants-Montjic          1
# Name: area, dtype: int64

# %% [markdown]
# 4 - Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
#
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.

# %%
#método .isin()
ataques2 = ataques[ataques["country"].isin(["AUSTRALIA", "USA"] )]
ataques2.head()
# Out:
#      case_number  unnamed:_0    year        type    country  \
# 0     2018.06.25           0  2018.0     Boating        USA
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21  2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35    2018.03.31          35  2018.0  Unprovoked        USA
#
#                  area                      location                 activity  \
# 0          California   Oceanside, San Diego County                 Paddling
# 8             Florida  Cocoa Beach, Brevard  County                  Walking
# 10         Queensland               Cairns Aquarium           Feeding sharks
# 21  Western Australia       Surfers Point, Prevelly                  Surfing
# 35             Hawaii                   Kukio Beach  Stand-Up Paddleboarding
#
#            name sex_ age     time          species_  \
# 0   Julie Wolfe    F  57    18h00       White shark
# ...

# %%
#le pasamos la condición or.
ataques3 = ataques[(ataques["country"] == "AUSTRALIA") |(ataques["country"] == "USA")]
ataques3.head()
# Out:
#      case_number  unnamed:_0    year        type    country  \
# 0     2018.06.25           0  2018.0     Boating        USA
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21  2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35    2018.03.31          35  2018.0  Unprovoked        USA
#
#                  area                      location                 activity  \
# 0          California   Oceanside, San Diego County                 Paddling
# 8             Florida  Cocoa Beach, Brevard  County                  Walking
# 10         Queensland               Cairns Aquarium           Feeding sharks
# 21  Western Australia       Surfers Point, Prevelly                  Surfing
# 35             Hawaii                   Kukio Beach  Stand-Up Paddleboarding
#
#            name sex_ age     time          species_  \
# 0   Julie Wolfe    F  57    18h00       White shark
# ...

# %% [markdown]
# 4.1 - ¿Cuántos ataques se han producido en cada país?

# %%
ataques_australia = ataques2.shape[0]-ataques_usa.shape[0]
ataques_australia
# Out:
# 324

# %%
ataques_usa.shape[0]
# Out:
# 719

# %%
print(f"El número de ataques de ambos paises son {ataques2.shape[0]}.")
# Out:
# El número de ataques de ambos paises son 1043.

# %%
print(f"El número de ataques que se han producido en Australia son {ataques_australia}.")
print(f"El número de ataques que se han producido en USA son {ataques_usa.shape[0]}.")
# Out:
# El número de ataques que se han producido en Australia son 324.
# El número de ataques que se han producido en USA son 719.

# %% [markdown]
# 4.2 - ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
paddling = ataques[(ataques["country"] == "AUSTRALIA") & (ataques["activity"] == "Paddling")]
paddling
# Out:
# Empty DataFrame
# Columns: [case_number, unnamed:_0, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %% [markdown]
# - No hay casos en Australia.

# %% [markdown]
# 4.3 - ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
año = ataques[(ataques["country"] == "AUSTRALIA") & (ataques["year"] < 2000)]
año.shape[0]
# Out:
# 151

# %% [markdown]
# 4.4 - ¿Y después del 2000?

# %%
año_despues = ataques[(ataques["country"] == "AUSTRALIA") & (ataques["year"] > 2000)]
año_despues.shape[0]
# Out:
# 167

# %% [markdown]
# 5 - Extraed unicamente los ataques a mujeres.

# %%
mujeres = ataques["sex_"] == "F"
mujeres.shape[0]
# Out:
# 1502

# %% [markdown]
# 6 - ¿Cuántas mujeres fueron atacadas en España?

# %%
mujeres_españa = ataques[(ataques["country"] == "SPAIN") & (ataques["sex_"] == "F")]
año.shape[0]
# Out:
# 151

# %% [markdown]
# 7 - Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
años_isin = ataques[ataques["year"].isin([1997, 2000, 2006])]
años_isin.head()
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 1407  2006.12.18        1412  2006.0  Unprovoked     AUSTRALIA
# 1408  2006.12.11        1413  2006.0  Unprovoked   NEW ZEALAND
# 1409  2006.12.10        1414  2006.0  Unprovoked           USA
# 1410  2006.12.06        1415  2006.0    Provoked  SOUTH AFRICA
# 1411  2006.12.02        1416  2006.0  Unprovoked     AUSTRALIA
#
#                    area                    location       activity  \
# 1407           Victoria      Winki Pop, Bells Beach        Surfing
# 1408       North Island            Raglan, Manu Bay        Surfing
# 1409         California  Dillon Beach, Marin County        Surfing
# 1410      KwaZulu-Natal                  Cape Vidal        Fishing
# 1411  Western Australia               Wharton Beach  Body boarding
#
#                       name sex_ age       time                   species_  \
# 1407          Peter Galvin    M  25      20h00           2.5 to 3 m shark
# ...

# %% [markdown]
# 8 - Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
ataques.species_.unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
patron = "^white|White\s\w+"

# %%
blanco = ataques[ataques["species_"].str.contains(patron, regex=True)]
blanco
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 0     2018.06.25           0  2018.0     Boating           USA
# 24    2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# 34    2018.04.03          34  2018.0  Unprovoked  SOUTH AFRICA
# 60    2017.11.24          60  2017.0  Unprovoked           USA
# 71    2017.10.22          71  2017.0  Unprovoked     AUSTRALIA
# ...          ...         ...     ...         ...           ...
# 5108  1927.12.28        5120  1927.0  Unprovoked  SOUTH AFRICA
# 5212  1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216  1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218  1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5528  1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                          location  \
# 0                California       Oceanside, San Diego County
# 24    Western Cape Province    Robberg Beach, Plettenberg Bay
# ...

# %% [markdown]
# 9 - Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
patron2 = "^white|tiger|White|Tiger\s\w+"

# %%
tigre = ataques[ataques["species_"].str.contains(patron2, regex=True)]
tigre
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18    2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23      2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24      2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# ...            ...         ...     ...         ...           ...
# 5148    1925.11.22        5160  1925.0  Unprovoked     AUSTRALIA
# 5212    1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216    1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218    1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                        location  \
# 0                California     Oceanside, San Diego County
# 6                Pernambuco           Piedade Beach, Recife
# ...

# %% [markdown]
# 10 - Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
ataques["siglo"] = np.where(ataques["year"] < 2000, "siglo-XX", "siglo-XXI")

# %%
ataques.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %% [markdown]
# 11 - Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
ataques.to_csv("./ficheros_pandas/attacks2.csv")
