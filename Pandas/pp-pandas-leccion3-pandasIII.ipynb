# %% [markdown]
# # Ejercicios Pair Programming - Módulo 2 Sprint 1
# ## Lección 3 - Pandas III
# ### Noemi Azorin y Silvia Gordón

# %%
import pandas as pd
import os
import locale
from locale import getpreferredencoding

# %% [markdown]
# 1.- Cargar el dataset
#
# 💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos puede dar error (puede que no os de error, si es así menos problemas!).  tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.

# %%
locale.getpreferredencoding("./ficheros_pandas/attacks.csv")
# Out:
# 'UTF-8'

# %%
tiburones = pd.read_csv("./ficheros_pandas/attacks.csv", encoding ="UTF-8", index_col = 0)
tiburones.head()
# Out:
#   Case Number    Year        Type    Country             Area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ...         Species           Investigator or Source  \
# 0  ...      White shark                R. Collier, GSAF
# ...

# %% [markdown]
# 2.- Haced una exploración básica del DataFrame:
#
# ¿Cuántas filas y columnas tiene el DataFrame?

# %%
tiburones.shape
# Out:
# (6114, 21)

# %% [markdown]
# Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %%
tiburones.head()
# Out:
#   Case Number    Year        Type    Country             Area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ...         Species           Investigator or Source  \
# 0  ...      White shark                R. Collier, GSAF
# ...

# %%
tiburones.tail()
# Out:
#        Case Number    Year          Type    Country               Area  \
# 6127  1804.02.26.R  1804.0          Boat  AUSTRALIA    New South Wales
# 6128    1803.05.17  1803.0  Sea Disaster        USA     South Carolina
# 6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 6130  1802.04.13.R  1802.0    Unprovoked      INDIA                NaN
# 6131  1801.12.18.R  1801.0      Provoked        NaN                NaN
#
#                               Location                         Activity  \
# 6127    Georges Head, off Port Jackson                              NaN
# 6128                    Off Charleston                              NaN
# 6129  Hamelin Harbour, at Faure Island                              NaN
# 6130                               NaN                              NaN
# 6131                               NaN  Standing on landed shark's tail
#
#                                  Name Sex   Age  ...   Species   \
# ...

# %% [markdown]
# Mostrad 2 filas al azar del DataFrame.

# %%
tiburones.sample(2)
# Out:
#        Case Number    Year        Type           Country              Area  \
# 4244  1956.08.00.a  1956.0  Unprovoked  PAPUA NEW GUINEA  Central Province
# 4255    1956.05.00  1956.0  Unprovoked         AUSTRALIA     Torres Strait
#
#                                    Location Activity        Name Sex   Age  \
# 4244  Fisherman's Island, near Port Moresby  Fishing  native boy    M  NaN
# 4255                                    NaN   Diving         NaN  NaN  NaN
#
#       ...          Species   \
# 4244  ...  2.3 m [7'] shark
# 4255  ...               NaN
#
#                                  Investigator or Source  \
# 4244  V.M. Coppleson (1958), pp.49-51; A. M. Rapson,...
# 4255                       V.M. Coppleson (1958), p.245
#
#                              pdf  \
# 4244  1956.08.00.a-NativeBoy.pdf
# 4255        1956.05.00-diver.pdf
#
#                                            href formula  \
# 4244  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %% [markdown]
# ¿Cuál es el nombre de las columnas del DataFrame?

# %%
tiburones.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
# Variables numéricas

tiburones.describe()
# Out:
#               Year  original order
# count  6114.000000     6114.000000
# mean   1968.831207     3237.445044
# std      43.745920     1769.652633
# min    1801.000000      172.000000
# 25%    1946.000000     1706.250000
# 50%    1980.000000     3236.500000
# 75%    2005.000000     4768.750000
# max    2018.000000     6303.000000

# %%
# Variables categoricas

tiburones.describe(include="object")
# Out:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %% [markdown]
# ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
porcentaje = (tiburones.isnull().sum()/(tiburones.shape[1])*100)
porcentaje
# Out:
# Case Number                   4.761905
# Year                          0.000000
# Type                         19.047619
# Country                     190.476190
# Area                       1942.857143
# Location                   2323.809524
# Activity                   2433.333333
# Name                        952.380952
# Sex                        2619.047619
# Age                       12695.238095
# Time                      15142.857143
# Species                   12880.952381
# Investigator or Source       76.190476
# pdf                           0.000000
# href formula                  4.761905
# href                          0.000000
# Case Number.1                 0.000000
# Case Number.2                 0.000000
# original order                0.000000
# Unnamed: 22               29109.523810
# Unnamed: 23               29104.761905
# dtype: float64

# %% [markdown]
# Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
tiburones.describe().value_counts()
# Out:
# Year         original order
# 43.745920    1769.652633       1
# 1801.000000  172.000000        1
# 1946.000000  1706.250000       1
# 1968.831207  3237.445044       1
# 1980.000000  3236.500000       1
# 2005.000000  4768.750000       1
# 2018.000000  6303.000000       1
# 6114.000000  6114.000000       1
# dtype: int64

# %%
diccionario1 = dict(tiburones["Year"].value_counts())    

type(diccionario1)
# Out:
# dict

# %%
diccionario2 = dict(tiburones["original order"].value_counts())    

type(diccionario2)
# Out:
# dict

# %% [markdown]
# Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.

# %%
columnas_nuevas = {col:col.lower().replace(" ", "_") for col in tiburones.columns}

# %%
tiburones.rename(columns=columnas_nuevas, inplace=True)
tiburones.head(2)
# Out:
#   case_number    year        type country        area  \
# 0  2018.06.25  2018.0     Boating     USA  California
# 1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity             name sex_ age  ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  57  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  11  ...
#
#       species_          investigator_or_source                     pdf  \
# 0  White shark                R. Collier, GSAF    2018.06.25-Wolfe.pdf
# 1          NaN  K.McMurray, TrackingSharks.com  2018.06.18-McNeely.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case_number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...

# %% [markdown]
# Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
tiburones.drop(labels= ["unnamed:_22", "unnamed:_23", "case_number.1", "case_number.2","original_order", "investigator_or_source", "pdf", "href_formula"], axis='columns', inplace = True)

# %% [markdown]
# Establece la columna Case Number como índice del DataFrame.

# %%
tiburones.set_index(["case_number"], inplace=True)
tiburones.head(2)
# Out:
#                year        type country        area  \
# case_number
# 2018.06.25   2018.0     Boating     USA  California
# 2018.06.18   2018.0  Unprovoked     USA     Georgia
#
#                                    location  activity             name sex_  \
# case_number
# 2018.06.25      Oceanside, San Diego County  Paddling      Julie Wolfe    F
# 2018.06.18   St. Simon Island, Glynn County  Standing  Adyson McNeely     F
#
#             age           time     species_  \
# case_number
# 2018.06.25   57          18h00  White shark
# 2018.06.18   11  14h00  -15h00          NaN
#
#                                                           href
# case_number
# 2018.06.25   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2018.06.18   http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 3.- Guarda el csv que no tiene esas columnas para seguir usándolo mañana.
#
# Descarga este csv para poder hacer los ejercicios de pair programming.

# %%
tiburones.to_csv("./ficheros_pandas/attacks1.csv")

# %% [markdown]
# Happy coding 🦈
